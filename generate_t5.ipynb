# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -qU torch==1.7.1 torchtext==0.8.0 torchvision==0.8.2
# !pip install -q transformers==4.4.2 pytorch_lightning==1.2.1 sentencepiece

# %%
## 学習済t5モデルのダウンロード
# !cd "drive/My Drive/ProfileGenerator/";wget https://www.dropbox.com/s/zpi7wltm8v5oo6c/t5.tar.gz
# !cd "drive/My Drive/ProfileGenerator/";tar xvfz "t5.tar.gz"
# Out:
# --2021-12-11 10:13:27--  https://www.dropbox.com/s/zpi7wltm8v5oo6c/t5.tar.gz
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/zpi7wltm8v5oo6c/t5.tar.gz [following]
# --2021-12-11 10:13:27--  https://www.dropbox.com/s/raw/zpi7wltm8v5oo6c/t5.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc81d1fbbb4bdd6482329029ba87.dl.dropboxusercontent.com/cd/0/inline/Bbp7dgNtNZxwNz7qRPLx7gydq6knNEskJdHBFrtUMLs9ndSvi-ebi7NLEnAbW8RgRPU6rEA3NrBx0MvfO4bWzsKMyeZbB0Pwg94xldntI7vRFb58G3goUYtbGns8iE4_RxF6hqvlQYPr8Hi6mLRlkbyD/file# [following]
# --2021-12-11 10:13:28--  https://uc81d1fbbb4bdd6482329029ba87.dl.dropboxusercontent.com/cd/0/inline/Bbp7dgNtNZxwNz7qRPLx7gydq6knNEskJdHBFrtUMLs9ndSvi-ebi7NLEnAbW8RgRPU6rEA3NrBx0MvfO4bWzsKMyeZbB0Pwg94xldntI7vRFb58G3goUYtbGns8iE4_RxF6hqvlQYPr8Hi6mLRlkbyD/file
# Resolving uc81d1fbbb4bdd6482329029ba87.dl.dropboxusercontent.com (uc81d1fbbb4bdd6482329029ba87.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6035:15::a27d:550f
# Connecting to uc81d1fbbb4bdd6482329029ba87.dl.dropboxusercontent.com (uc81d1fbbb4bdd6482329029ba87.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BboK_LmSOiFkUkrhcix2exwggAh3WDw7lCDABBEKMsIfWkIuB8YF0OcbAT78PtfSqXmPnEsQTzYMIAv8NXnOJBBw6egQANk7QENEPTQPci4Z-HwRlKv7eUlu6MIwpNyufpGYIvMedco4d6oznb0QrE3w83911VEA-ndzPNKdubqHtxIgZf4AZAJIFHGnJdwzBbvkuD596LyG2_JBAmgFR43GO-G6BKbPj4y1Z2KUdpwkBZs8ddAnyf0erCbAv0QwWP29NMOj9FK_WCROM0Q9QVtWKkKxCqBwXEpnq4znwwOxbkba-Z7dppDcU-cbMubE9sfrjN4ImbIyNev1m0lQrbUOY5f1FMoyVmdiwFcQkkxhhnp93CGYa8WYGmTHtP16WK0/file [following]
# --2021-12-11 10:13:29--  https://uc81d1fbbb4bdd6482329029ba87.dl.dropboxusercontent.com/cd/0/inline2/BboK_LmSOiFkUkrhcix2exwggAh3WDw7lCDABBEKMsIfWkIuB8YF0OcbAT78PtfSqXmPnEsQTzYMIAv8NXnOJBBw6egQANk7QENEPTQPci4Z-HwRlKv7eUlu6MIwpNyufpGYIvMedco4d6oznb0QrE3w83911VEA-ndzPNKdubqHtxIgZf4AZAJIFHGnJdwzBbvkuD596LyG2_JBAmgFR43GO-G6BKbPj4y1Z2KUdpwkBZs8ddAnyf0erCbAv0QwWP29NMOj9FK_WCROM0Q9QVtWKkKxCqBwXEpnq4znwwOxbkba-Z7dppDcU-cbMubE9sfrjN4ImbIyNev1m0lQrbUOY5f1FMoyVmdiwFcQkkxhhnp93CGYa8WYGmTHtP16WK0/file
# Reusing existing connection to uc81d1fbbb4bdd6482329029ba87.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 823727157 (786M) [application/octet-stream]
# Saving to: ‘t5.tar.gz’
#
# t5.tar.gz           100%[===================>] 785.57M  16.7MB/s    in 51s
#
# 2021-12-11 10:14:21 (15.3 MB/s) - ‘t5.tar.gz’ saved [823727157/823727157]
#
# ._t5
# t5/
# t5/._config.json
# tar: Ignoring unknown extended header keyword 'SCHILY.fflags'
# t5/config.json
# t5/._special_tokens_map.json
# tar: Ignoring unknown extended header keyword 'SCHILY.fflags'
# t5/special_tokens_map.json
# t5/._spiece.model
# tar: Ignoring unknown extended header keyword 'SCHILY.fflags'
# t5/spiece.model
# t5/._tokenizer_config.json
# tar: Ignoring unknown extended header keyword 'SCHILY.fflags'
# t5/tokenizer_config.json
# t5/._pytorch_model.bin
# tar: Ignoring unknown extended header keyword 'SCHILY.fflags'
# t5/pytorch_model.bin

# %%
import argparse
import glob
import os
import json
import time
import logging
import random
import re
import codecs
from itertools import chain
from string import punctuation

import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl

main_path = "/content/drive/My Drive/ProfileGenerator/"

from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)

# 乱数シードの設定
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(42)

# %%
# GPU利用有無
USE_GPU = torch.cuda.is_available()

# 各種ハイパーパラメータ
args_dict = dict(
    learning_rate=3e-4,
    weight_decay=0.0,
    adam_epsilon=1e-8,
    warmup_steps=0,
    gradient_accumulation_steps=1,


    n_gpu=1 if USE_GPU else 0,
    early_stop_callback=False,
    fp_16=False,
    opt_level='O1',
    max_grad_norm=1.0,
    seed=42,
)
# 学習に用いるハイパーパラメータを設定する
args_dict.update({
    "max_input_length":  30,  # 入力文の最大トークン数
    "max_target_length": 512,  # 出力文の最大トークン数
    "train_batch_size":  8,  # 訓練時のバッチサイズ
    "eval_batch_size":   8,  # テスト時のバッチサイズ
    "num_train_epochs":  8,  # 訓練するエポック数
    })

# %%
class ProfileDataset(Dataset):
    def __init__(self, tokenizer, list_input, input_max_len=512, target_max_len=512):
        self.list_input = list_input
        self.input_max_len = input_max_len
        self.target_max_len = target_max_len
        self.tokenizer = tokenizer
        self.inputs = []
        self.targets = []

        self._build()
  
    def __len__(self):
        return len(self.inputs)
  
    def __getitem__(self, index):
        source_ids = self.inputs[index]["input_ids"].squeeze()
        source_mask = self.inputs[index]["attention_mask"].squeeze()
        return {"source_ids": source_ids, "source_mask": source_mask}
  
    def _build(self):
        for input in self.list_input:
            tokenized_inputs = self.tokenizer.batch_encode_plus(
                [input], max_length=self.input_max_len, truncation=True, 
                padding="max_length", return_tensors="pt"
            )
            self.inputs.append(tokenized_inputs)

# %%
import textwrap
from tqdm.auto import tqdm
from sklearn import metrics

def get_output(args_dict,tokenizer,trained_model,list_input):
   # テストデータの読み込み
    test_dataset = ProfileDataset(tokenizer, list_input, 
                            input_max_len=args_dict["max_input_length"], 
                            target_max_len=args_dict["max_target_length"])

    test_loader = DataLoader(test_dataset, batch_size=8, num_workers=4)

    trained_model.eval()

    inputs = []
    outputs = []

    for batch in tqdm(test_loader):
        input_ids = batch['source_ids']
        input_mask = batch['source_mask']
        if USE_GPU:
            input_ids = input_ids.cuda()
            input_mask = input_mask.cuda()

        output = trained_model.generate(input_ids=input_ids, 
          attention_mask=input_mask, 
          max_length=args_dict["max_target_length"],
          repetition_penalty=10.0,   # 同じ文の繰り返し（モード崩壊）へのペナルティ
            )

        output_text = [tokenizer.decode(ids, skip_special_tokens=True, 
                              clean_up_tokenization_spaces=False) 
                  for ids in output]
        input_text = [tokenizer.decode(ids, skip_special_tokens=True, 
                                clean_up_tokenization_spaces=False) 
                  for ids in input_ids]

        inputs.extend(input_text)
        outputs.extend(output_text)
    return inputs,outputs

# %%
# 事前学習済みモデル
PRETRAINED_MODEL_NAME = "sonoisa/t5-base-japanese"

# 転移学習済みモデル
MODEL_DIR = f"{main_path}/t5"
# トークナイザー（SentencePiece）モデルの読み込み
tokenizer = T5Tokenizer.from_pretrained(PRETRAINED_MODEL_NAME, is_fast=True)
# 学習済みモデル
trained_model = T5ForConditionalGeneration.from_pretrained(MODEL_DIR)

# GPUの利用有無
USE_GPU = torch.cuda.is_available()
if USE_GPU:
    trained_model.cuda()

# %%
#サンプルテキストを読み込んで生成
file_path = f"{main_path}/sample_text/sample_fixed.txt"
list_input = codecs.open(file_path,encoding="utf-8")
for input, output in zip(*get_output(args_dict,tokenizer,trained_model,list_input)):
    print("title:     " + input)
    print("generated: " + output)
    print()
# Out:
#   0%|          | 0/3 [00:20<?, ?it/s]
# title:     巫女 妹 三 中 失敗 行動 何 政治 アニメ 本 目の当たり グレイ
# generated: 【人名】の巫女で、【人名】の妹。三姉妹の中で唯一失敗を許さない行動を取るが、何かと政治に疎い一面も持つ。アニメ第1作では本性を目の当たりにしたグレイモンによって倒される。
#
# title:     妹 夫 巫女 嘘 経験 教師 父 武装 社員 宇宙 2 母
# generated: 【人名】の妹で、【人名】の夫。巫女である父に嘘をついていた経験があり、教師として働きたいと願っている。父が武装会社の社員だったこともあり、宇宙へ飛び立つことを夢見ている。第2期では母が行方不明になり、妹と共に暮らしている。
#
# title:     ナンバー 国 妹 妻 巫女 体 公 時代 武器 免許 作 現在
# generated: ナンバー2。【人名】国の皇女で、ユグドラシルの妹。妻は巫女であり、体に鎧を纏っている。公女時代は武器の免許を持っていなかったが、本作では現在の身分である。
#
# title:     中 巫女 興味 妹 家 オーナー 精 サポート 幽霊 エル 手 クラスメート
# generated: 中2。巫女に興味があり、妹の【人名】が住む家のオーナーを務める霊能者。精霊に精通しており、サポート役でもある。幽霊や妖怪を怖がるエルにも手を差し伸べている。クラスメートからは「お姉ちゃん」と呼ばれている。
#
# title:     妹 巫女 会長 相手 為 2 種族 評議 権利 野
# generated: 【人名】の妹で巫女。【人名】学園の生徒会長を務めており、その実力はクラスメイト相手にも引けを取らない程である為、2種族間の評議権争いでは野望を果たそうとしていた。
#
# title:     巫女 漫画 抜 一 妹 正 復活 アニメ 二 訓練 授業 女の子
# generated: 【人名】の巫女で、漫画版では抜一の妹。【人名】が正気を取り戻したことで復活する。アニメ第二期では訓練生として登場し、授業も担当している。女の子にモテるらしい。
#
# title:     財閥 エネルギー 妹 巫女 試合 任務 生前 戦闘 服 見た目 オレンジ ドイツ
# generated: 【人名】財閥の令嬢。エネルギーを操る能力を持つ。【人名】の妹で、巫女として試合に勝つことを任務としている。生前は戦闘服のような服を着ており、見た目もオレンジである。ドイツ・ケルン出身。
#
# title:     巫女 弟 人 妹 夫 印象 巻 普段 存在 1 後 放送
# generated: 【人名】の巫女で、【人名】の弟。人懐っこい性格だが、妹思いな一面も持つ。夫に似ておっちょこちょいな印象がある。第1巻から登場。後にテレビアニメ版にも登場している。
#
# title:     巫女 特徴 親 妹 開始 ショップ 服 仲間 23 頭 利用 手
# generated: 巫女装束が特徴の少女。親に捨てられた妹を捜すため、物語開始前にショップで服を買い漁っていたところを【人名】と出会い、彼女と仲間になる。23歳。頭は良いが少々臆病なところがあり、それを利用されて手痛い目に遭うことも多い。
#
# title:     妹 巫女 自身 親衛隊 場 部隊 2 米 歌手 所 言葉遣い 団
# generated: 【人名】の妹で、【人名】の巫女。自身を「親衛隊」と称しており、その場に居合わせた他の部隊から慕われている。第2期では米歌手を目指している所だが、言葉遣いが荒いため団からは嫌われている。
#
# title:     俺 国 刀 妹 巫女 0 アニメ チーム 子供 女 勝利
# generated: 俺の国の刀鍛冶の妹。巫女装束をまとい、0(アニメでは2)に着替えている。【人名】チームの子供達からは「お姉ちゃん」と呼ばれている。女好きで男勝りな性格だが、負けず嫌いな一面も持つ。勝利のためには手段を選ばない冷酷さを持つ。
#
# title:     話 妹 エネルギー 長男 巫女 男の子 官 何 自身 個人 シャーマン
# generated: 性別不明/初登場回第218話「【人名】とおむすびまん」おかあさんの妹でエネルギーの精霊。長男であり、巫女のような格好をした男の子。神官として何をやらせてもらっているが、彼自身はシャーマンである。
#
# title:     巫女 妹 客 幼なじみ 笑い 経 時代 版 過去 タイプ 反抗 犬
# generated: 【人名】の巫女で、【人名】の妹。お客様からの信頼も厚く、【人名】とは幼なじみである。「笑い」と「経文」が口癖だが、古風な言葉遣いをする。平安時代には既に亡くなっているらしく、アニメ版では過去世を生き返らせるタイプとなっている。反抗的な性格であり、犬夜叉や々(かっこう)とも仲が良い。
#
# title:     巫女 話 会 彼女 妹 中等 一 彼 事件 例 60 血縁
# generated: 【人名】の巫女。第1話で【人名】と会っているが、彼女自身は妹である。中等部一年生であり、彼にまつわる事件を例に挙げると60人ほどいるらしい。なお、血縁関係はない模様。
#
# title:     野球 戦い 妹 奴 巫女 あだ名 23 少女 の アイドル 連続 期
# generated: 野球の戦いが終わった後、妹の【人名】と共に「奴良組」にやってきた巫女。あだ名は「お姉ちゃん」。23歳の少女で、一人称は「ボク」。可愛いものが大好きだが、女の子らしくないのが玉に瑕。アイドルとしては連続第1期から登場。
#
# title:     ダンス 妹 機 土 巫女 兄 姫 ハート 1 逮捕 歌手 際
# generated: ダンスが得意な妹。機土の巫女で、兄を慕っている。【人名】姫に恋心を抱いており、「ハート・オブ・ザ・デイズ」では1度逮捕されているが、歌手デビューの際は兄のことを「お姉ちゃん」と呼んでいた。
#
# title:     頃 実家 巫女 帽子 妹 帝国 2 学園 特技 女 長 坊
# generated: 幼い頃から実家の巫女をやっており、常に帽子をかぶっている。妹が帝国学園2年生で、特技は女装と裁縫。【人名】からは「長坊」と呼ばれている。
#
# title:     巫女 攻撃 事 妹 彼女 1 2 節 名前 鼻 屋
# generated: 【人名】の巫女。【人名】の攻撃を防ぐ事ができ、その能力で妹を苦しめたが、彼女自身は1度も死なずに済んだ(2度目は助かった)節がある。名前の由来は「鼻」から。かなりの恥ずかしがり屋だが、意外と優しい一面もある。
#
# title:     設定 巫女 相手 ワン 妹 赤 悪事 2 小学校 際 名 士
# generated: 設定上は「巫女」で、相手がワンピース姿の少女。妹に赤ずきんがいる。悪事を働くことを嫌う。2年前、小学校へ転校する際に名付け親として名を馳せた魔道士である。
#
# title:     子 モデル 技 巫女 妹 姉妹 終了 宇宙 投 兄弟 志 神
# generated: 【人名】の子で、【人名】の姉。モデルとなった技は巫女装束をまとい、妹のように可愛がっていた。三姉妹終了後、宇宙へ投身自殺を図るも兄弟共々神に斬られた。

# %%
#サンプルテキストを読み込んで生成2
file_path = f"{main_path}/sample_text/sample_fixed.txt"
list_input = codecs.open(file_path,encoding="utf-8")
for input, output in zip(*get_output(args_dict,tokenizer,trained_model,list_input)):
    print("title:     " + input)
    print("generated: " + output)
    print()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# title:     巫女 妹 三 中 失敗 行動 何 政治 アニメ 本 目の当たり グレイ
# generated: 【人名】の巫女で、【人名】の妹。三姉妹の中で唯一失敗を許さない行動を取るが、何かと政治に疎い一面も持つ。アニメ第1作では本性を目の当たりにしたグレイモンによって倒される。
#
# title:     妹 夫 巫女 嘘 経験 教師 父 武装 社員 宇宙 2 母
# generated: 【人名】の妹で、【人名】の夫。巫女である父に嘘をついていた経験があり、教師として働きたいと願っている。父が武装会社の社員だったこともあり、宇宙へ飛び立つことを夢見ている。第2期では母が行方不明になり、妹と共に暮らしている。
#
# title:     ナンバー 国 妹 妻 巫女 体 公 時代 武器 免許 作 現在
# generated: ナンバー2。【人名】国の皇女で、ユグドラシルの妹。妻は巫女であり、体に鎧を纏っている。公女時代は武器の免許を持っていなかったが、本作では現在の身分である。
#
# title:     中 巫女 興味 妹 家 オーナー 精 サポート 幽霊 エル 手 クラスメート
# generated: 中2。巫女に興味があり、妹の【人名】が住む家のオーナーを務める霊能者。精霊に精通しており、サポート役でもある。幽霊や妖怪を怖がるエルにも手を差し伸べている。クラスメートからは「お姉ちゃん」と呼ばれている。
#
# title:     妹 巫女 会長 相手 為 2 種族 評議 権利 野
# generated: 【人名】の妹で巫女。【人名】学園の生徒会長を務めており、その実力はクラスメイト相手にも引けを取らない程である為、2種族間の評議権争いでは野望を果たそうとしていた。
#
# title:     巫女 漫画 抜 一 妹 正 復活 アニメ 二 訓練 授業 女の子
# generated: 【人名】の巫女で、漫画版では抜一の妹。【人名】が正気を取り戻したことで復活する。アニメ第二期では訓練生として登場し、授業も担当している。女の子にモテるらしい。
#
# title:     財閥 エネルギー 妹 巫女 試合 任務 生前 戦闘 服 見た目 オレンジ ドイツ
# generated: 【人名】財閥の令嬢。エネルギーを操る能力を持つ。【人名】の妹で、巫女として試合に勝つことを任務としている。生前は戦闘服のような服を着ており、見た目もオレンジである。ドイツ・ケルン出身。
#
# title:     巫女 弟 人 妹 夫 印象 巻 普段 存在 1 後 放送
# generated: 【人名】の巫女で、【人名】の弟。人懐っこい性格だが、妹思いな一面も持つ。夫に似ておっちょこちょいな印象がある。第1巻から登場。後にテレビアニメ版にも登場している。
#
# title:     巫女 特徴 親 妹 開始 ショップ 服 仲間 23 頭 利用 手
# generated: 巫女装束が特徴の少女。親に捨てられた妹を捜すため、物語開始前にショップで服を買い漁っていたところを【人名】と出会い、彼女と仲間になる。23歳。頭は良いが少々臆病なところがあり、それを利用されて手痛い目に遭うことも多い。
#
# title:     妹 巫女 自身 親衛隊 場 部隊 2 米 歌手 所 言葉遣い 団
# generated: 【人名】の妹で、【人名】の巫女。自身を「親衛隊」と称しており、その場に居合わせた他の部隊から慕われている。第2期では米歌手を目指している所だが、言葉遣いが荒いため団からは嫌われている。
#
# title:     俺 国 刀 妹 巫女 0 アニメ チーム 子供 女 勝利
# generated: 俺の国の刀鍛冶の妹。巫女装束をまとい、0(アニメでは2)に着替えている。【人名】チームの子供達からは「お姉ちゃん」と呼ばれている。女好きで男勝りな性格だが、負けず嫌いな一面も持つ。勝利のためには手段を選ばない冷酷さを持つ。
#
# title:     話 妹 エネルギー 長男 巫女 男の子 官 何 自身 個人 シャーマン
# generated: 性別不明/初登場回第218話「【人名】とおむすびまん」おかあさんの妹でエネルギーの精霊。長男であり、巫女のような格好をした男の子。神官として何をやらせてもらっているが、彼自身はシャーマンである。
#
# title:     巫女 妹 客 幼なじみ 笑い 経 時代 版 過去 タイプ 反抗 犬
# generated: 【人名】の巫女で、【人名】の妹。お客様からの信頼も厚く、【人名】とは幼なじみである。「笑い」と「経文」が口癖だが、古風な言葉遣いをする。平安時代には既に亡くなっているらしく、アニメ版では過去世を生き返らせるタイプとなっている。反抗的な性格であり、犬夜叉や々(かっこう)とも仲が良い。
#
# title:     巫女 話 会 彼女 妹 中等 一 彼 事件 例 60 血縁
# generated: 【人名】の巫女。第1話で【人名】と会っているが、彼女自身は妹である。中等部一年生であり、彼にまつわる事件を例に挙げると60人ほどいるらしい。なお、血縁関係はない模様。
#
# title:     野球 戦い 妹 奴 巫女 あだ名 23 少女 の アイドル 連続 期
# generated: 野球の戦いが終わった後、妹の【人名】と共に「奴良組」にやってきた巫女。あだ名は「お姉ちゃん」。23歳の少女で、一人称は「ボク」。可愛いものが大好きだが、女の子らしくないのが玉に瑕。アイドルとしては連続第1期から登場。
#
# title:     ダンス 妹 機 土 巫女 兄 姫 ハート 1 逮捕 歌手 際
# generated: ダンスが得意な妹。機土の巫女で、兄を慕っている。【人名】姫に恋心を抱いており、「ハート・オブ・ザ・デイズ」では1度逮捕されているが、歌手デビューの際は兄のことを「お姉ちゃん」と呼んでいた。
#
# title:     頃 実家 巫女 帽子 妹 帝国 2 学園 特技 女 長 坊
# generated: 幼い頃から実家の巫女をやっており、常に帽子をかぶっている。妹が帝国学園2年生で、特技は女装と裁縫。【人名】からは「長坊」と呼ばれている。
#
# title:     巫女 攻撃 事 妹 彼女 1 2 節 名前 鼻 屋
# generated: 【人名】の巫女。【人名】の攻撃を防ぐ事ができ、その能力で妹を苦しめたが、彼女自身は1度も死なずに済んだ(2度目は助かった)節がある。名前の由来は「鼻」から。かなりの恥ずかしがり屋だが、意外と優しい一面もある。
#
# title:     設定 巫女 相手 ワン 妹 赤 悪事 2 小学校 際 名 士
# generated: 設定上は「巫女」で、相手がワンピース姿の少女。妹に赤ずきんがいる。悪事を働くことを嫌う。2年前、小学校へ転校する際に名付け親として名を馳せた魔道士である。
#
# title:     子 モデル 技 巫女 妹 姉妹 終了 宇宙 投 兄弟 志 神
# generated: 【人名】の子で、【人名】の姉。モデルとなった技は巫女装束をまとい、妹のように可愛がっていた。三姉妹終了後、宇宙へ投身自殺を図るも兄弟共々神に斬られた。

# %%
# !pip install gensim==3.8.3
# Out:
# Requirement already satisfied: gensim==3.8.3 in /usr/local/lib/python3.7/dist-packages (3.8.3)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.3) (1.19.5)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.3) (1.4.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.3) (5.2.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.3) (1.15.0)

# %%
from gensim import corpora
from gensim.models.ldamodel import LdaModel

def load_lda_and_dict():
    ldafile = f"{main_path}/lda/test.lda"
    dictfile = f"{main_path}/lda/test.dict"
    lda = LdaModel.load(ldafile)
    dictionary = corpora.Dictionary.load(dictfile)
    return lda,dictionary

def expand_zokusei(list_zokusei,lda,dictionary):
    bow = dictionary.doc2bow(list_zokusei)
    list_tupl = lda.get_document_topics(bow)
    list_term, list_prob = [], []
    for topicid, prob in list_tupl:
        list_term_tupl = lda.get_topic_terms(topicid,topn=100)
        list_term += [term for term, prob in list_term_tupl]
        list_prob += [prob for term, prob in list_term_tupl]

    get_term = list_zokusei+[word for word in set([dictionary[word_id] for word_id in random.choices(list_term, weights=list_prob, k=10)]) if word not in list_zokusei]
    first_half = get_term[:5]
    last_half = get_term[5:]
    random.shuffle(first_half)
    return first_half+last_half

def generate_zokusei(lda,dictionary):
    topics = lda.get_topics()
    topic_inds = random.choices([ri for ri in range(len(topics))],k=1)
    word_dist = [prob/len(topic_inds) for topic in topics for prob in topic]
    ind_dist = [ri for topic in topics for ri in range(len(topic))]
    ind_list = random.choices(ind_dist,weights= word_dist,k=10)
    list_word = [word for word in set([dictionary[ind] for ind in ind_list])]
    return list_word

# %%
#属性語を指定してプロフィール文を生成
lda,dictionary = load_lda_and_dict()
list_zokusei = "ツインテール 小学生".split(" ")
list_expanded_zokusei = [" ".join(expand_zokusei(list_zokusei,lda,dictionary)) for _ in range(20)]
for input, output in zip(*get_output(args_dict,tokenizer,trained_model,list_expanded_zokusei)):
    print("title:     " + input)
    print("generated: " + output)
    print()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# title:     弟 小学生 ツインテール 両親 好意 3 系 学園 姉 屋 世界
# generated: 【人名】の弟で小学生。髪型はツインテール。両親に好意を抱いており、【人名】と3人でよくつるんでいる。体育会系の学園に通う姉の面倒見も良いが、やや恥ずかしがり屋な一面もある。世界中を旅しているらしい。
#
# title:     代表 小学生 運動 2 ツインテール 兄 コンプレックス 部 もの 息子 部員
# generated: 【人名】代表。小学生ながら運動神経抜群で、【人名】の2つ年上の兄にコンプレックスを抱いている。陸上部に所属していたものの、成績はあまり芳しくない模様。息子と同じく水泳部員である。
#
# title:     組 部 ツインテール 小学生 風紀 姉 パン 話 部員 成績
# generated: 1年組→2年C組の男子生徒。中等部3年生。ツインテールの小学生。風紀委員をしている姉がいる。パンが大好物で、第6話では女子部員として成績優秀であることが判明する。
#
# title:     キャラ アニメ 小学生 1 ツインテール もの パン 新聞 息子 一 初代 卒業
# generated: 【人名】のキャラ。アニメオリジナルキャラクター。小学生1年生。髪型はツインテール。好きなものはパンと新聞。嫌いなものは息子一人。初代最終回で【人名】が卒業式に着ていた服を譲り受けた。
#
# title:     人物 小学生 彼女 ツインテール 2 ゲーム 所 長髪 性格 一 卒業
# generated: 作中の人物。【人名】の小学生時代の同級生で、彼女のツインテールを2つにまとめている。ゲーム版では少し抜けた所がある長髪の女性だが、性格は大人びていておっとりしている。一度卒業したら卒業するつもりらしい。
#
# title:     1 ツインテール 小学生 弟 好意 両親 住人 兄 救出 外見
# generated: 1年。髪型はツインテール。小学生の弟がいる。【人名】に好意を抱いているが、両親や住人からは「兄ちゃん」と呼ばれている。妹救出作戦の最中、姉と瓜二つな外見で再会する。
#
# title:     好意 キャラ 代表 ツインテール 小学生 高校 作 部 学園 姉 本人 双子
# generated: 【人名】に好意を寄せているキャラの代表格。ツインテールの小学生で、高校1年生(作中では3年生)。【人名】と同じ高等部2年組に在籍しており、学園では姉のように振舞っているが、本人は「双子の妹」としか思っていない。
#
# title:     2 際 弟 小学生 ツインテール 人物 姉 銀 息子 部員 外見 恨み
# generated: 2年。背番号8番。【人名】が転校した際の弟で、小学生の頃はツインテールだった。他の人物からは「姉ちゃん」と呼ばれている。銀の息子であり、テニス部員でもある。外見に似合わず強気な性格をしており、兄に対して強い恨みを抱いている。
#
# title:     ツインテール 際 弟 小学生 結婚 運動 キャラ 兄 謎 卒業
# generated: 【人名】がツインテールにした際の【人名】の弟。小学生の時に結婚し、運動神経抜群なキャラで兄を羨ましがっていた。謎多き人物であり、卒業式の際にも謎の転校生として登場している。
#
# title:     小学生 ツインテール 2 両親 萌え ブラジル 成績 パン 少女 性格 双子 大学
# generated: 小学生の頃はツインテールだったが、中学2年の時にツインテールになった。両親が萌え系ブラジル人のため成績も優秀でパンツ一丁の少女だが、性格は姉と瓜二つである。双子の妹・【人名】がいる。大学受験に失敗して中退し、実家に居候している。
#
# title:     歴史 ツインテール 弟 暴力 小学生 11 組 小学校 進学 行方 成績
# generated: 歴史教師。ツインテールの姉がいる。弟に暴力をふるう小学生11人組の末っ子で、小学校進学後に行方不明となる。成績優秀だがおっちょこちょいな一面もある。
#
# title:     小学生 ツインテール 歴史 オープニング 弟 とき もの 姉 前年 卒業 双子 大学
# generated: 【人名】の小学生時代の同級生。ツインテールで眼鏡をかけている。【人名】の歴史を知っているらしく、オープニングやエンディングにも度々登場している。弟が3人いる(そのときは「兄」と呼んでいた)ものの、姉とはあまり仲が良くない様子。前年卒業した双子の大学に通っている模様。
#
# title:     両親 ツインテール 弟 在籍 小学生 新聞 話 性格 外見 学園 大学
# generated: 両親は離婚しており、ツインテールの姉と弟がいる。【人名】学園初等部に在籍する小学生で、新聞部に所属している。アニメ第1話より登場。性格は大人びており、外見も幼い少女である。桐朋学園大学に通っているが、成績はあまり芳しくない模様。
#
# title:     1 11 ツインテール 在籍 小学生 両親 初代 関係 屋 学園 行方
# generated: 1年。背番号11番。金髪のツインテールで、眼鏡をかけている。【人名】学園に在籍していた頃は小学生だったが、両親が初代校長の関係から寂しがり屋な性格になり、学校をサボって行方をくらましていた。
#
# title:     小学生 彼女 両親 キャラ ツインテール 部 曰く ゲーム 外見 成績
# generated: 【人名】の小学生時代のクラスメイトで、彼女と同じく両親が作ったキャラ。髪型はツインテール。中等部1年生(【人名】曰く「ゲームよりゲームの方が好き」)。外見に反して成績は優秀である。
#
# title:     キャラ 小学生 ツインテール 際 弟 3 部 先輩 息子 性格
# generated: キャラ弁が得意な小学生。髪型はツインテールで、眼鏡をかけている。【人名】と初めて会った際に「兄ちゃん」と呼んでいた。弟がいる。第3期では中等部1年生の先輩として登場し、息子を溺愛している。性格はおっちょこちょいなところがある。
#
# title:     楽観 小学生 ツインテール 兄 両親 ゲーム 姉 進学 新聞 性格 外見 双子
# generated: 楽観的な小学生。髪型はツインテール。兄が両親を亡くしたため、ゲーム好きの姉に育てられた。高校進学後は新聞部所属となる。明るく前向きな性格で、外見も双子とは思えないほど大人びている。
#
# title:     ツインテール 存在 姉 3 小学生 謎 一 屋 学園 大学
# generated: ツインテールの少女で、【人名】にとって憧れの存在。姉が3人おり、小学生とは思えないほど謎が多い。一人称は「私」。実家は一軒屋を営んでおり、学園都市にある大学に通っている。
#
# title:     小学生 ラン ツインテール 父親 オープニング 失踪 風紀 11 両親 性格 屋 尊敬
# generated: 【人名】の小学生時代のクラスメイト。ランとツインテールが特徴。父親はオープニングで失踪したことになっているが、風紀委員を勤める11歳の少年である。両親とは正反対の性格をしており、恥ずかしがり屋な一面もある。【人名】のことを尊敬している。
#
# title:     味方 小学生 ツインテール 好意 人物 謎 息子 外見 初代 大学
# generated: 【人名】の味方である小学生。髪型はツインテール。【人名】に好意を抱いている人物で、謎が多い。息子と外見が似ているためか、第1期では初代『.C...』から登場している。大学受験を控えているらしい。

# %%
#ランダムに属性語を生成してプロフィール文を生成
lda,dictionary = load_lda_and_dict()
list_expanded_zokusei = [" ".join(generate_zokusei(lda,dictionary)) for _ in range(20)]
for input, output in zip(*get_output(args_dict,tokenizer,trained_model,list_expanded_zokusei)):
    print("title:     " + input)
    print("generated: " + output)
    print()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# title:     豪 験 親愛 人物 実 紫 少尉 媛 性格 式
# generated: 豪胆で、験体に秀でている。【人名】を親愛する人物だが、実の姉である紫媛には頭が上がらない。性格は温厚かつおっとりとしており、式神や精霊にも優しく接している。
#
# title:     気 キス 穢れ 試験 バンド 胸 愛 生徒 宇宙 毎回
# generated: 気の弱い【人名】にキスをして穢れを祓わせる。試験中はヘアバンドで胸を隠している。愛する生徒には「宇宙」と呼ばせているが、毎回その度に嫌がっている。
#
# title:     枢 その後 クラスメイト 友人 寿 少女 戦い 本人 ユーリ 3000
# generated: 【人名】枢のクラスメイトで友人。【人名】寿に好意を寄せている少女。戦いを好まないが、本人曰く「ユーリは3000歳以上」らしい。
#
# title:     年 際 部屋 動作 け 間柄 存在 安定 保険 者
# generated: 【人名】が年老いた際、【人名】の住む部屋に引っ越してきた少女。動作は軽く「けっこうキツイ」という程度の間柄ではあるものの、存在自体は安定しており、「保険」として加入している者も多い。
#
# title:     子供 研究 事 態度 親友 周 父 魔術 秋 接客
# generated: 【人名】の子供時代の友人。【人名】が研究に没頭している事に対して、冷淡な態度で接する事が多い。親友である周の父から魔術を教わっており、秋からは「お兄ちゃん」と呼ばれている。接客業にも長けている。
#
# title:     気 城 2 その後 能力 理解 もの 店主 先行 世界
# generated: 【人名】の気を引こうと【人名】城に乗り込むが、2度目の襲撃で敗北する。その後能力は理解できたものの、店主に先行き不測の事態のため世界から追放される。
#
# title:     飛鳥 上司 1 島 故郷 アニメ 抗争 プロ 歌唱 互
# generated: 飛鳥の上司。第1話から登場。【人名】島を故郷としている。アニメでは「」と抗争するプロ歌手で、歌唱力も高い。互いを認め合う仲である。
#
# title:     何 販売 重 敵 ゼロ ほど ミッキー 転送 相手 記念
# generated: 何十年も販売員として働いており、重度の敵はゼロと言っていいほどいる。ミッキーの転送能力で相手が死んだら記念品を渡すことができる。
#
# title:     発射 上層 島 持ち主 ネタ 年齢 エピソード 金 暴れ 帰還
# generated: 【人名】が発射した【人名】の上層階にある「島」の持ち主。元ネタは『.C..』の年齢相応のエピソードで、金に汚く大暴れして地球へ帰還しようとしていた所を助けられた人物。
#
# title:     一方 本名 議員 悪魔 当初 噂 存在 16 足場 故
# generated: 【人名】の一方的なリーダー。本名不明。【人名】議員から「悪魔」と評されている。当初は噂に過ぎなかった存在だったが、16話で足場を失ったが故か復活する。
#
# title:     宣言 人物 銀 海 4 特徴 序盤 心 父 給料
# generated: 【人名】と【人名】が「宣言」した人物。銀の海で出会った4人のうちの1人。金髪に三つ編みが特徴。序盤では心優しい少年だったが、終盤には心を閉ざし父を恨むようになる。給料日前でも家事を手伝っている。
#
# title:     総合 襲撃 世の中 二 髪 ゴミ 性格 馬 時期 逮捕
# generated: 【人名】総合病院の医師。【人名】が襲撃された際、世の中を憂いていると語っていた。二つ名は「ゴミ捨て場」。々とした性格で、馬に轢かれそうになるなど散々な目に遭う時期があったが、後に逮捕された。
#
# title:     勘違い 娘 自分 奮闘 鬼 ヒーロー 営業 酒店 癖 聴覚
# generated: 【人名】の勘違いで、【人名】の娘。自分の娘を守ろうと奮闘する鬼のようなヒーローに憧れている。普段は営業している酒店に勤めているが、酔っ払う癖があり聴覚が鈍い。
#
# title:     体質 戦 キャラクター 幽霊 キテレツ ほど マシ 命 村 京
# generated: 不治の病を患う病弱な少女。好戦的なキャラクターで、幽霊やキテレツにも怖がられるほどだが、マシに命を救われた過去を持つ。【人名】村では京妖怪との戦いで瀕死の重傷を負いながらも生き延びている。
#
# title:     運動 牢獄 教師  始末 オッサン ネタ ファイト 熱 地球
# generated: 運動神経抜群で、【人名】を牢獄に閉じ込めた教師。の始末もオッサンネタである。ファイト熱は地球最強と謳われている。
#
# title:     自分 ナイト 森 常識 定 ヘア 抜 一 親友 消息
# generated: 自分のことを「ナイト」と呼ばせる、森で一番の常識人。髪型は定規に縛られたロングヘアだが、抜群のスタイルを誇る。【人名】とは一時親友だったが、その後消息不明となる。
#
# title:     薫 その後 位 作者 由来 警察 麻 母 人々 コンビ
# generated: 【人名】薫の母親。その後、【人名】家に居候する。年齢は15歳位(作者曰く「18歳」)。名前の由来は警察に捕まった麻の母を助けたことがきっかけである。家族や周囲の人々とのコンビネーションが絶妙で、よく一緒に行動している。
#
# title:     花屋 先王 距離 支援 英国 住民 刺青 仮面 構成 凄腕
# generated: 花屋「先王」の主人。【人名】とは距離を置いていたが、支援してくれた英国住民に恩義を感じている。刺青を彫った仮面で構成する凄腕の女性。
#
# title:     原 ジャン 趣味 思い出 20 状態 場面 嬢 うち 22
# generated: 原語版『ジャン・レノ』に登場。趣味は読書で、若い頃の思い出を20冊以上残すほどの本を読んでいるが、その状態でも全く覚えていない場面が多い。お嬢様学校に通っているうちに22歳になったらしい。
#
# title:     物腰 送り 旅行 3 ゲーム 己 黒子 話 自宅 邪
# generated: 物腰が柔らかく、【人名】の送り込んだ旅行会社を3日で潰すなどゲーム好き。己のことを「黒子」と呼ぶ。第2話では自宅に招いた邪馬台と対峙する。
